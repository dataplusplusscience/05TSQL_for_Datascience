# %% [markdown]
# # SQL in Python: AdventureWorks Database Business Analysis
#
# Welcome to my project: SQL in Python - AdventureWorks Database Business Analysis. In this project, I utilize with Python to perform data analysis on the AdventureWorks database, leveraging the power of SQL queries to gain valuable insights into business operations.
#
# Join me on this exciting journey as I explore the data, analyze trends, and uncover key patterns to drive informed decision-making. Let's dive into the world of AdventureWorks and unleash the potential of SQL in Python! 🚀

# %% [markdown]
# ## Python Code for SQL Data Analysis
# The  code snippet that performs SQL data analysis in Python using libraries such as `pyodbc`, `os`, `dotenv`, and `pandas`.

# %%
import pyodbc
import os
import pandas as pd

# %%
#Check if drivers are installed
[x for x in pyodbc.drivers() if x.startswith("Microsoft Access Driver")]
# Out:
# ['Microsoft Access Driver (*.mdb, *.accdb)']

# %%
# Define the connection string
conn_str = (
    r'DRIVER={ODBC Driver 17 for SQL Server};'
    r'SERVER=localhost;'
    r'DATABASE=AdventureWorksLT2022;'
    r'Trusted_Connection=yes;'
)

# %%
# Establish the connection
conn = pyodbc.connect(conn_str)

# Create a cursor
cursor = conn.cursor()

# %%
# execute a query
cursor.execute('SELECT * FROM SalesLT.Address')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
df_address = pd.DataFrame(data)

# %%
df_address.head()
# Out:
#    AddressID         AddressLine1 AddressLine2      City StateProvince  \
# 0          9    8713 Yosemite Ct.         None   Bothell    Washington
# 1         11  1318 Lasalle Street         None   Bothell    Washington
# 2         25     9178 Jumping St.         None    Dallas         Texas
# 3         28     9228 Via Del Sol         None   Phoenix       Arizona
# 4         32    26910 Indela Road         None  Montreal        Quebec
#
#    CountryRegion PostalCode                               rowguid ModifiedDate
# 0  United States      98011  268AF621-76D7-4C78-9441-144FD139821A   2006-07-01
# 1  United States      98011  981B3303-ACA2-49C7-9A96-FB670785B269   2007-04-01
# 2  United States      75201  C8DF3BD9-48F0-4654-A8DD-14A67A84D3C6   2006-09-01
# 3  United States      85004  12AE5EE1-FC3E-468B-9B92-3B970B169774   2005-09-01
# 4         Canada    H1Y 2H5  84A95F62-3AE8-4E7E-BBD5-5A6F00CD982D   2006-08-01

# %%
# execute a query
cursor.execute('SELECT * FROM SalesLT.Customer')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
df_customer = pd.DataFrame(data)
df_customer.head()
# Out:
#    CustomerID  NameStyle Title FirstName MiddleName    LastName Suffix  \
# 0           1      False   Mr.   Orlando         N.         Gee   None
# 1           2      False   Mr.     Keith       None      Harris   None
# 2           3      False   Ms.     Donna         F.    Carreras   None
# 3           4      False   Ms.     Janet         M.       Gates   None
# 4           5      False   Mr.      Lucy       None  Harrington   None
#
#                   CompanyName               SalesPerson  \
# 0                A Bike Store   adventure-works\pamela0
# 1          Progressive Sports    adventure-works\david8
# 2    Advanced Bike Components  adventure-works\jillian0
# 3       Modular Cycle Systems  adventure-works\jillian0
# 4  Metropolitan Sports Supply      adventure-works\shu0
#
#                    EmailAddress         Phone  \
# 0  orlando0@adventure-works.com  245-555-0173
# 1    keith0@adventure-works.com  170-555-0127
# 2    donna0@adventure-works.com  279-555-0130
# ...

# %%
# execute a query
cursor.execute('SELECT * FROM SalesLT.CustomerAddress')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
df_customer_address = pd.DataFrame(data)
df_customer_address.head()
# Out:
#    CustomerID  AddressID  AddressType                               rowguid  \
# 0       29485       1086  Main Office  16765338-DBE4-4421-B5E9-3836B9278E63
# 1       29486        621  Main Office  22B3E910-14AF-4ED5-8B4D-23BBE757414D
# 2       29489       1069  Main Office  A095C88B-D7E6-4178-A078-2ECA44214801
# 3       29490        887  Main Office  F12E1702-D897-4035-B614-0FE2C72168A9
# 4       29492        618  Main Office  5B3B3EB2-3F43-47ED-A20C-23697DABF23B
#
#   ModifiedDate
# 0   2007-09-01
# 1   2005-09-01
# 2   2005-07-01
# 3   2006-09-01
# 4   2006-12-01

# %%
# execute a query
cursor.execute('SELECT * FROM SalesLT.Product')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
df_product = pd.DataFrame(data)
df_product.head()
# Out:
#    ProductID                       Name ProductNumber  Color StandardCost  \
# 0        680  HL Road Frame - Black, 58    FR-R92B-58  Black    1059.3100
# 1        706    HL Road Frame - Red, 58    FR-R92R-58    Red    1059.3100
# 2        707      Sport-100 Helmet, Red     HL-U509-R    Red      13.0863
# 3        708    Sport-100 Helmet, Black       HL-U509  Black      13.0863
# 4        709     Mountain Bike Socks, M     SO-B909-M  White       3.3963
#
#    ListPrice  Size   Weight  ProductCategoryID  ProductModelID SellStartDate  \
# 0  1431.5000    58  1016.04                 18               6    2002-06-01
# 1  1431.5000    58  1016.04                 18               6    2002-06-01
# 2    34.9900  None     None                 35              33    2005-07-01
# 3    34.9900  None     None                 35              33    2005-07-01
# 4     9.5000     M     None                 27              18    2005-07-01
#
#   SellEndDate DiscontinuedDate  \
# ...

# %%
# execute a query
cursor.execute('SELECT * FROM SalesLT.ProductCategory')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
df_product_category = pd.DataFrame(data)
df_product_category.head()
# Out:
#    ProductCategoryID  ParentProductCategoryID            Name  \
# 0                  1                      NaN           Bikes
# 1                  2                      NaN      Components
# 2                  3                      NaN        Clothing
# 3                  4                      NaN     Accessories
# 4                  5                      1.0  Mountain Bikes
#
#                                 rowguid ModifiedDate
# 0  CFBDA25C-DF71-47A7-B81B-64EE161AA37C   2002-06-01
# 1  C657828D-D808-4ABA-91A3-AF2CE02300E9   2002-06-01
# 2  10A7C342-CA82-48D4-8A38-46A2EB089B74   2002-06-01
# 3  2BE3BE36-D9A2-4EEE-B593-ED895D97C2A6   2002-06-01
# 4  2D364ADE-264A-433C-B092-4FCBF3804E01   2002-06-01

# %%
# execute a query
cursor.execute('SELECT * FROM SalesLT.ProductDescription')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
df_product_description = pd.DataFrame(data)
df_product_description.head()
# Out:
#    ProductDescriptionID                                        Description  \
# 0                     3                                    Chromoly steel.
# 1                     4       Aluminum alloy cups; large diameter spindle.
# 2                     5             Aluminum alloy cups and a hollow axle.
# 3                     8  Suitable for any type of riding, on or off-roa...
# 4                    64  This bike delivers a high-level of performance...
#
#                                 rowguid ModifiedDate
# 0  301EED3A-1A82-4855-99CB-2AFE8290D641   2007-06-01
# 1  DFEBA528-DA11-4650-9D86-CAFDA7294EB0   2007-06-01
# 2  F7178DA7-1A7E-4997-8470-06737181305E   2007-06-01
# 3  8E6746E5-AD97-46E2-BD24-FCEA075C3B52   2007-06-01
# 4  7B1C4E90-85E2-4792-B47B-E0C424E2EC94   2007-06-01

# %%
# execute a query
cursor.execute('SELECT * FROM SalesLT.ProductModel')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
df_product_model = pd.DataFrame(data)
df_product_model.head()
# Out:
#    ProductModelID                Name CatalogDescription  \
# 0               1        Classic Vest               None
# 1               2         Cycling Cap               None
# 2               3  Full-Finger Gloves               None
# 3               4  Half-Finger Gloves               None
# 4               5   HL Mountain Frame               None
#
#                                 rowguid ModifiedDate
# 0  29321D47-1E4C-4AAC-887C-19634328C25E   2007-06-01
# 1  474FB654-3C96-4CB9-82DF-2152EEFFBDB0   2005-06-01
# 2  A75483FE-3C47-4AA4-93CF-664B51192987   2006-06-01
# 3  14B56F2A-D4AA-40A4-B9A2-984F165ED702   2006-06-01
# 4  FDD5407B-C2DB-49D1-A86B-C13A2E3582A2   2005-06-01

# %%
# execute a query
cursor.execute('SELECT * FROM SalesLT.SalesOrderDetail')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
df_sales_order_detail = pd.DataFrame(data)
df_sales_order_detail.head()
# Out:
#    SalesOrderID  SalesOrderDetailID  OrderQty  ProductID UnitPrice  \
# 0         71774              110562         1        836  356.8980
# 1         71774              110563         1        822  356.8980
# 2         71776              110567         1        907   63.9000
# 3         71780              110616         4        905  218.4540
# 4         71780              110617         2        983  461.6940
#
#   UnitPriceDiscount   LineTotal                               rowguid  \
# 0            0.0000  356.898000  E3A1994C-7A68-4CE8-96A3-77FDD3BBD730
# 1            0.0000  356.898000  5C77F557-FDB6-43BA-90B9-9A7AEC55CA32
# 2            0.0000   63.900000  6DBFE398-D15D-425E-AA58-88178FE360E5
# 3            0.0000  873.816000  377246C9-4483-48ED-A5B9-E56F005364E0
# 4            0.0000  923.388000  43A54BCD-536D-4A1B-8E69-24D083507A14
#
#   ModifiedDate
# 0   2008-06-01
# 1   2008-06-01
# 2   2008-06-01
# 3   2008-06-01
# 4   2008-06-01

# %%
# execute a query
cursor.execute('SELECT * FROM SalesLT.SalesOrderHeader')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
df_sales_order_header = pd.DataFrame(data)
df_sales_order_header.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         71774               2 2008-06-01 2008-06-13 2008-06-08       5
# 1         71776               2 2008-06-01 2008-06-13 2008-06-08       5
# 2         71780               2 2008-06-01 2008-06-13 2008-06-08       5
# 3         71782               2 2008-06-01 2008-06-13 2008-06-08       5
# 4         71783               2 2008-06-01 2008-06-13 2008-06-08       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  ...  \
# 0            False          SO71774         PO348186287  10-4020-000609  ...
# 1            False          SO71776       PO19952192051  10-4020-000106  ...
# 2            False          SO71780       PO19604173239  10-4020-000340  ...
# 3            False          SO71782       PO19372114749  10-4020-000582  ...
# 4            False          SO71783       PO19343113609  10-4020-000024  ...
#
# ...

# %% [markdown]
# ### Monthly Sales Trend:

# %%
# execute a query
cursor.execute('''SELECT
 DATEPART(MONTH, OrderDate) AS Month,
 SUM(TotalDue) AS TotalSales
FROM
 SalesLT.SalesOrderHeader
WHERE
 DATEPART(YEAR, OrderDate) = 2008
GROUP BY
 DATEPART(MONTH, OrderDate)
ORDER BY
 Month;''')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
monthly_sales_trend = pd.DataFrame(data)
monthly_sales_trend.head()
# Out:
#    Month   TotalSales
# 0      6  956303.5949

# %% [markdown]
# ### Customer Segment Analysis

# %%
# execute a query
cursor.execute('''SELECT
 C.CustomerID,
 COUNT(O.SalesOrderID) AS OrderCount,
 SUM(O.TotalDue) AS TotalRevenue
FROM
 SalesLT.SalesOrderHeader O
JOIN
 SalesLT.Customer C
 ON O.CustomerID = C.CustomerID
GROUP BY
 C.CustomerID;''')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
cust_segment_analysis = pd.DataFrame(data)
cust_segment_analysis.head()
# Out:
#    CustomerID  OrderCount TotalRevenue
# 0       29485           1   43962.7901
# 1       29531           1    7330.8972
# 2       29546           1   98138.2131
# 3       29568           1    2669.3183
# 4       29584           1     272.6468

# %% [markdown]
# ### Best Selling Products

# %%
# execute a query
cursor.execute('''SELECT TOP 10
 P.Name AS ProductName,
 SUM(D.LineTotal) AS TotalRevenue,
 SUM(D.OrderQty) AS TotalQuantitySold
FROM
 SalesLT.SalesOrderDetail D
JOIN
 SalesLT.Product P
 ON D.ProductID = P.ProductID
GROUP BY
 P.Name
ORDER BY
 TotalRevenue DESC;;''')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
cust_segment_analysis = pd.DataFrame(data)
cust_segment_analysis.head()
# Out:
#                ProductName  TotalRevenue  TotalQuantitySold
# 0    Touring-1000 Blue, 60  37191.492000                 26
# 1   Mountain-200 Black, 42  37178.838000                 27
# 2    Road-350-W Yellow, 48  36486.235500                 42
# 3   Mountain-200 Black, 38  35801.844000                 26
# 4  Touring-1000 Yellow, 60  23413.474656                 17

# %% [markdown]
# ### Repeat Customers

# %%
# execute a query
cursor.execute('''SELECT
 C.FirstName + C.LastName AS CustomerName,
 COUNT(O.SalesOrderID) AS TotalOrders,
 SUM(O.TotalDue) AS TotalSpent
FROM
 SalesLT.SalesOrderHeader O
JOIN
 SalesLT.Customer C
 ON O.CustomerID = C.CustomerID
GROUP BY
 C.FirstName, C.LastName
HAVING
 COUNT(O.SalesOrderID) > 1
ORDER BY
 TotalSpent DESC;''')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
cust_segment_analysis = pd.DataFrame(data)
cust_segment_analysis.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Age Group Analysis

# %%
# execute a query
cursor.execute('''SELECT
 CASE
     WHEN Age >= 18 AND Age <= 30 THEN '18–30'
     WHEN Age > 30 AND Age <= 45 THEN '31–45'
     WHEN Age > 45 AND Age <= 60 THEN '46–60'
 ELSE 'Above 60'
 END AS AgeGroup,
 COUNT(*) AS TotalCustomers,
 SUM(O.TotalDue) AS TotalRevenue
FROM
 (
 SELECT
 CustomerID,
 DATEDIFF(YEAR, BirthDate, GETDATE()) AS Age
 FROM
 SalesLT.Customer
 ) C
JOIN
 SalesLT.SalesOrderHeader O
 ON C.CustomerID = O.CustomerID
GROUP BY
 AgeGroup
ORDER BY
 AgeGroup;''')

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Get the column names
columns = [column[0] for column in cursor.description]

# Convert the rows into a list of dictionaries
data = [dict(zip(columns, row)) for row in rows]

# Create a DataFrame from the list of dictionaries
cust_segment_analysis = pd.DataFrame(data)
cust_segment_analysis.head()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[42], line 2
#       1 # execute a query
# ----> 2 cursor.execute('''SELECT
#       3  CASE
#       4      WHEN Age >= 18 AND Age <= 30 THEN '18–30'
#       5      WHEN Age > 30 AND Age <= 45 THEN '31–45'
#       6      WHEN Age > 45 AND Age <= 60 THEN '46–60'
#       7  ELSE 'Above 60'
#       8  END AS AgeGroup,
#       9  COUNT(*) AS TotalCustomers,
#      10  SUM(O.TotalDue) AS TotalRevenue
#      11 FROM
#      12  (
#      13  SELECT
#      14  CustomerID,
#      15  DATEDIFF(YEAR, BirthDate, GETDATE()) AS Age
#      16  FROM
#      17  SalesLT.Customer
#      18  ) C
#      19 JOIN
#      20  SalesLT.SalesOrderHeader O
#      21  ON C.CustomerID = O.CustomerID
#      22 GROUP BY
#      23  AgeGroup
#      24 ORDER BY
#      25  AgeGroup;''')
#      27 # Fetch all rows from the executed query
# ...

# %%
# Close the connection
conn.close()
